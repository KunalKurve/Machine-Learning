# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, GridSearchCV, train_test_split
from sklearn.metrics import r2_score
import os

# %%
os.chdir(r"D:\March 2024\PML\Datasets")

# %%
concrete = pd.read_csv("Concrete_Data.csv")
concrete
# Out:
#       Cement  Blast    Fly  Water  Superplasticizer  Coarse   Fine  Age  \
# 0      540.0    0.0    0.0  162.0               2.5  1040.0  676.0   28
# 1      540.0    0.0    0.0  162.0               2.5  1055.0  676.0   28
# 2      332.5  142.5    0.0  228.0               0.0   932.0  594.0  270
# 3      332.5  142.5    0.0  228.0               0.0   932.0  594.0  365
# 4      198.6  132.4    0.0  192.0               0.0   978.4  825.5  360
# ...      ...    ...    ...    ...               ...     ...    ...  ...
# 1025   276.4  116.0   90.3  179.6               8.9   870.1  768.3   28
# 1026   322.2    0.0  115.6  196.0              10.4   817.9  813.4   28
# 1027   148.5  139.4  108.6  192.7               6.1   892.4  780.0   28
# 1028   159.1  186.7    0.0  175.6              11.3   989.6  788.9   28
# 1029   260.9  100.5   78.3  200.6               8.6   864.5  761.5   28
#
#       Strength
# 0        79.99
# 1        61.89
# 2        40.27
# 3        41.05
# 4        44.30
# ...

# %%
clf = IsolationForest(random_state=24)
clf.fit(concrete)
predictions = clf.predict(concrete)

# %%
print("%age of outliers="+ str((predictions<0).mean()*100)+ "%")
abn_ind = np.where(predictions < 0)
print("Outliers:")
print(concrete.index[abn_ind])
# Out:
# %age of outliers=22.815533980582526%
# Outliers:
# Index([   0,    1,    2,    3,    4,    6,   12,   17,   19,   20,
#        ...
#         987,  988,  990,  991,  992, 1008, 1014, 1016, 1019, 1024],
#       dtype='int64', length=235)

# %%
lr = LinearRegression()
# kfold = KFold(n_splits=5, shuffle=True, random_state=24)

concrete1 = concrete.drop('Cement', axis=1)

X = concrete1.drop('Strength', axis=1)
y = concrete1['Strength']


params = {}

gscv = GridSearchCV(lr, param_grid=params ,cv = kfold, scoring="r2")

# X_train, y_train, X_test, y_test = train_test_split(X, y, test_size=0.3,shuffle=True, random_state=24)

# lr.fit(X_train, y_train)
# y_pred = lr.predict(X_test)
# print("R2 score Data with outliers: ",r2_score(y_pred,y_test) )

gscv.fit(X, y)
print("R2 score Data with outliers: ",gscv.best_score_)
# Out:
# R2 score Data with outliers:  0.5297939833810256

# %%
for ind in abn_ind[0]:
    concrete = concrete.drop(ind)
concrete
# Out:
#       Cement  Blast    Fly  Water  Superplasticizer  Coarse   Fine  Age  \
# 5      266.0  114.0    0.0  228.0               0.0   932.0  670.0   90
# 7      380.0   95.0    0.0  228.0               0.0   932.0  594.0   28
# 8      266.0  114.0    0.0  228.0               0.0   932.0  670.0   28
# 9      475.0    0.0    0.0  228.0               0.0   932.0  594.0   28
# 10     198.6  132.4    0.0  192.0               0.0   978.4  825.5   90
# ...      ...    ...    ...    ...               ...     ...    ...  ...
# 1025   276.4  116.0   90.3  179.6               8.9   870.1  768.3   28
# 1026   322.2    0.0  115.6  196.0              10.4   817.9  813.4   28
# 1027   148.5  139.4  108.6  192.7               6.1   892.4  780.0   28
# 1028   159.1  186.7    0.0  175.6              11.3   989.6  788.9   28
# 1029   260.9  100.5   78.3  200.6               8.6   864.5  761.5   28
#
#       Strength
# 5        47.03
# 7        36.45
# 8        45.85
# 9        39.29
# 10       38.07
# ...

# %%
lr = LinearRegression()
# kfold = KFold(n_splits=5, shuffle=True, random_state=24)

concrete1 = concrete.drop('Cement', axis=1)

X = concrete1.drop('Strength', axis=1)
y = concrete1['Strength']


params = {}

gscv = GridSearchCV(lr, param_grid=params ,cv = kfold, scoring="r2")

# X_train, y_train, X_test, y_test = train_test_split(X, y, test_size=0.3,shuffle=True, random_state=24)

# lr.fit(X_train, y_train)
# y_pred = lr.predict(X_test)
# print("R2 score Data with outliers: ",r2_score(y_pred,y_test) )

gscv.fit(X, y)
print("R2 score Data without outliers: ",gscv.best_score_)
# Out:
# R2 score Data without outliers:  0.6459179685163814
