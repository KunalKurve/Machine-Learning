# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
pizza = pd.read_csv('pizza.csv')
print(pizza)
# Out:
#     Promote  Sales
# 0        23    554
# 1        56   1339
# 2        34    815
# 3        25    609
# 4        67   1600
# 5        82   2000
# 6        46   1000
# 7        14    300
# 8         6    150
# 9        47   1150
# 10       52   1200
# 11       88   2000
# 12       71   1750
# 13       78   2000
# 14       66   1500
# 15       44   1000
# 16       68   1600
# 17       90   2000
# 18       22    550

# %%
xi = pizza['Promote']
yi = pizza['Sales']
n = pizza.shape[0]

# %%
xbar = np.mean(xi)
ybar = np.mean(yi)

# %%
m_xi_yi = np.sum(xi * yi) / n
m_xi_2 = np.sum(xi ** 2) / n

# %%
b1 = (m_xi_yi - (xbar * ybar))/(m_xi_2 - (xbar ** 2))
b0 = ybar - (b1 * xbar)

# %% [markdown]
# ###############################################################################

# %% [markdown]
# Why do we put '[[]]'?
# - X should be 2D Numpy Array to perform dot fit. y can be 1D or 2D array

# %%
X = pizza[['Promote']]
y = pizza['Sales']

# %%
lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# 5.4858653632529695
# [23.50640302]

# %% [markdown]
# ###############################################################################

# %% [markdown]
# linag: in numpy, used to perform linear algebra

# %%
A = np.array([[2,1],[3,2]])
b = np.array([4,7])

print(np.linalg.solve(A, b))
# Out:
# [1. 2.]

# %% [markdown]
# ###############################################################################

# %%
insure = pd.read_csv('Insure_auto.csv', index_col = 0)
insure
# Out:
#         Home  Automobile  Operating_Cost
# Branch
# B01      400        1200          124000
# B02      350         360           71000
# B03      600         800          136000
# B04      800        1800          219000
# B05      900        1600          230000
# B06      200        1000           75000
# B07      120         900           56000
# B08      340        1100          110000
# B09      490         900          120000
# B10      700         800          144000

# %%
x1i = insure['Home']
x2i = insure['Automobile']
yi = insure['Operating_Cost']
n = insure.shape[0]

# %%
x1bar = np.mean(x1i)
x2bar = np.mean(x2i)
ybar = np.mean(yi)

# %%
sum_x1i_yi = np.sum(x1i * yi)
sum_x1i = np.sum(x1i)
sum_x1i_2 = np.sum(x1i ** 2)
sum_x1i_x2i = np.sum(x1i * x2i)
sum_x2i_yi = np.sum(x2i * yi)
sum_x2i = np.sum(x2i)
sum_x2i_2 = np.sum(x2i ** 2)

# %%
# b1 = (m_xi_yi - (xbar * ybar))/(m_xi_2 - (xbar ** 2))
# b0 = ybar - (b1 * xbar)

# %%
A = np.array([[sum_x1i, sum_x1i_2, sum_x1i_x2i],
              [sum_x2i, sum_x1i_x2i, sum_x2i_2],
              [1, x1bar, x2bar]])

b = np.array([sum_x1i_yi, sum_x2i_yi, ybar])

# %%
print("Using Linear Algebra:", np.linalg.solve(A, b))
# Out:
# Using Linear Algebra: [-10084.21313095    167.32668857     54.10529229]

# %%
X = insure[['Home', 'Automobile']]
y = insure['Operating_Cost']

# %%
lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
print("Linear Regression Intercept:",lr.intercept_)
print("Linear Regression Coefficient:",lr.coef_)
# Out:
# Linear Regression Intercept: -10084.213130948774
# Linear Regression Coefficient: [167.32668857  54.10529229]

# %% [markdown]
# Sklearn has generalised what we have done above
